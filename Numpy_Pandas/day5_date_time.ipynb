# %% [markdown]
# ### Part of day 5 notebook

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Supermarket Sales 2.csv")   # read CSV
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %%
df

# %%
from datetime import datetime

# %%
df

# %%
ans = datetime.strptime(df['Date'][1046],"%m/%d/%Y").strftime("%d-%m-%Y")  # it change only one columns date in our formate

# %%
ans

# %%
all_date = []
for date in df["Date"] :
    all_date.append(datetime.strptime(date,"%m/%d/%Y").strftime("%d-%m-%Y"))

# %%
date_series = pd.Series(all_date)
print(date_series)                           # it change only one columns date in our formate

# %%
df["Date"] = date_series

# %%
df["Date"]

# %%
df["Date"].head()

# %%
df["Date"].head(10)

# %%
df["Date"].tail()

# %%
df["Date"].tail(10)

# %%
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %% [markdown]
# - pandas only accept universal formate

# %%
df["Date"] = pd.to_datetime(df["Date"])   # convert datetime type
df["Date"]
# Out:
# 0      2024-01-01
# 1      2024-01-01
# 2      2024-01-01
# 3      2024-01-01
# 4      2024-01-01
#           ...
# 5048   2024-12-31
# 5049   2024-12-31
# 5050   2024-12-31
# 5051   2024-12-31
# 5052   2024-12-31
# Name: Date, Length: 5053, dtype: datetime64[ns]
