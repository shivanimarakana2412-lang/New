# %%
import pandas as pd

# %%
df = pd.read_csv("Supermarket Sales 2.csv")   # read CSV

# %%
# df.to_excel("Car_sales.xlsx", index=False)
# df = pd.read_excel("Car_sales.xlsx" ,sheet_name="main")

# %%
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %%
df.head() # first 5 values are given when arrguments are given
# Out:
#        Date     Branch Customer type  Gender      Product line  Unit price  \
# 0  1/1/2024   Brooklyn        Member  Female  Food & Beverages       84.63
# 1  1/1/2024     Queens        Normal  Female       Electronics       63.22
# 2  1/1/2024   Brooklyn        Normal  Female       Electronics       74.71
# 3  1/1/2024     Queens        Member  Female   Sports & Travel       36.98
# 4  1/1/2024  Manhattan        Member  Female   Sports & Travel       27.04
#
#    Quantity      Payment  Rating
# 0        10  Credit card     9.0
# 1         2         Cash     8.5
# 2         6         Cash     6.7
# 3        10  Credit card     7.0
# 4         4      Ewallet     6.9

# %%
df.head(10)# first 10 values are given
# Out:
#        Date     Branch Customer type  Gender      Product line  Unit price  \
# 0  1/1/2024   Brooklyn        Member  Female  Food & Beverages       84.63
# 1  1/1/2024     Queens        Normal  Female       Electronics       63.22
# 2  1/1/2024   Brooklyn        Normal  Female       Electronics       74.71
# 3  1/1/2024     Queens        Member  Female   Sports & Travel       36.98
# 4  1/1/2024  Manhattan        Member  Female   Sports & Travel       27.04
# 5  1/1/2024  Manhattan        Normal  Female    Fashion & Accs       65.74
# 6  1/1/2024  Manhattan        Member    Male  Home & Lifestyle       47.59
# 7  1/1/2024  Manhattan        Normal    Male   Sports & Travel       72.61
# 8  1/1/2024     Queens        Normal    Male   Health & Beauty       62.87
# 9  1/1/2024   Brooklyn        Normal    Male  Food & Beverages       21.12
#
#    Quantity      Payment  Rating
# 0        10  Credit card     9.0
# 1         2         Cash     8.5
# 2         6         Cash     6.7
# ...

# %%
df.tail() #last 5 value are given when arrguments are given
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 5048        6.71        10         Cash     5.9
# 5049        6.79         9  Credit card     4.8
# 5050       85.05         7      Ewallet     4.4
# 5051       54.64        10  Credit card     4.8
# 5052       49.75         7         Cash     5.8

# %%
df.tail(10) #last 10 value are given
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 5043  12/31/2024   Brooklyn        Member  Female   Sports & Travel
# 5044  12/31/2024  Manhattan        Member  Female       Electronics
# 5045  12/31/2024  Manhattan        Member    Male   Health & Beauty
# 5046  12/31/2024     Queens        Member    Male  Home & Lifestyle
# 5047  12/31/2024     Queens        Normal  Female       Electronics
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 5043       71.73         6  Credit card     7.1
# 5044       73.14         4      Ewallet     8.8
# 5045       25.32        10      Ewallet     3.3
# ...

# %%
df.sample() # random data given from whole data
# Out:
#           Date     Branch Customer type Gender      Product line  Unit price  \
# 241  1/23/2024  Manhattan        Member   Male  Food & Beverages       98.53
#
#      Quantity      Payment  Rating
# 241         6  Credit card     4.0

# %%
df.sample(10)
# Out:
#            Date     Branch Customer type  Gender      Product line  \
# 2542  7/20/2024   Brooklyn        Normal  Female  Food & Beverages
# 4052  11/7/2024     Queens        Normal  Female  Food & Beverages
# 1453  4/30/2024   Brooklyn        Normal  Female   Health & Beauty
# 2397   7/9/2024     Queens        Member  Female   Health & Beauty
# 1411  4/26/2024     Queens        Normal  Female  Food & Beverages
# 2168  6/22/2024   Brooklyn        Member  Female   Health & Beauty
# 716    3/4/2024  Manhattan        Member    Male   Health & Beauty
# 3207   9/9/2024     Queens        Normal    Male   Health & Beauty
# 906   3/20/2024  Manhattan        Normal    Male  Food & Beverages
# 1662  5/14/2024   Brooklyn        Normal    Male  Food & Beverages
#
#       Unit price  Quantity      Payment  Rating
# 2542        6.93         2  Credit card     7.2
# 4052        2.12        10  Credit card     9.1
# 1453       56.69         9  Credit card     8.4
# ...

# %%
df.isna() # missing value handle
# Out:
#        Date  Branch  Customer type  Gender  Product line  Unit price  \
# 0     False   False          False   False         False       False
# 1     False   False          False   False         False       False
# 2     False   False          False   False         False       False
# 3     False   False          False   False         False       False
# 4     False   False          False   False         False       False
# ...     ...     ...            ...     ...           ...         ...
# 5048  False   False          False   False         False       False
# 5049  False   False          False   False         False       False
# 5050  False   False          False   False         False       False
# 5051  False   False          False   False         False       False
# 5052  False   False          False   False         False       False
#
#       Quantity  Payment  Rating
# 0        False    False   False
# 1        False    False   False
# 2        False    False   False
# ...

# %%
df.isna().sum() # missing value handle
# Out:
# Date             0
# Branch           0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Payment          0
# Rating           0
# dtype: int64

# %% [markdown]
# - here datetime formate but we have seperated file for it

# %%
df.isnull().sum()
# Out:
# Date             0
# Branch           0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Payment          0
# Rating           0
# dtype: int64

# %%
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %%
df.dropna(inplace=True)  # original data formate change ---> for missing value handle

# %%
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %%
df.isna().sum()
# Out:
# Date             0
# Branch           0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Payment          0
# Rating           0
# dtype: int64

# %%
df["Customer type"] = df["Customer type"].fillna("-")  # for missing value replace by(-)

# %%
df
# Out:
#             Date     Branch Customer type  Gender      Product line  \
# 0       1/1/2024   Brooklyn        Member  Female  Food & Beverages
# 1       1/1/2024     Queens        Normal  Female       Electronics
# 2       1/1/2024   Brooklyn        Normal  Female       Electronics
# 3       1/1/2024     Queens        Member  Female   Sports & Travel
# 4       1/1/2024  Manhattan        Member  Female   Sports & Travel
# ...          ...        ...           ...     ...               ...
# 5048  12/31/2024  Manhattan        Normal  Female  Food & Beverages
# 5049  12/31/2024   Brooklyn        Normal    Male  Food & Beverages
# 5050  12/31/2024     Queens        Member    Male       Electronics
# 5051  12/31/2024  Manhattan        Member  Female   Sports & Travel
# 5052  12/31/2024     Queens        Normal  Female   Health & Beauty
#
#       Unit price  Quantity      Payment  Rating
# 0          84.63        10  Credit card     9.0
# 1          63.22         2         Cash     8.5
# ...

# %%
#df["Unit price"].fillna(df["Unit price"].mean(),inplace = True) --->this is change in version 3.0

# %%
df.isna().sum()
# Out:
# Date             0
# Branch           0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Payment          0
# Rating           0
# dtype: int64

# %%
df.duplicated() # for copy is available or not to check
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5048    False
# 5049    False
# 5050    False
# 5051    False
# 5052    False
# Length: 5053, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(inplace=True) # for change

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Date              object
# Branch            object
# Customer type     object
# Gender            object
# Product line      object
# Unit price       float64
# Quantity           int64
# Payment           object
# Rating           float64
# dtype: object
