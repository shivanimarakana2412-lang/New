# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## series

# %%
# one dimensional array like structure along with indices as label

# %%
s1 = pd.Series([34 , 28 ,62 ,365 ,79 , 64 ,19 , 69]) # series givea index
s1
# Out:
# 0     34
# 1     28
# 2     62
# 3    365
# 4     79
# 5     64
# 6     19
# 7     69
# dtype: int64

# %%
print(s1[0])
print(s1[1])
print(s1[2])
print(s1[3])
print(s1[4])
print(s1[5])
print(s1[6])
print(s1[7])
# Out:
# 34
# 28
# 62
# 365
# 79
# 64
# 19
# 69

# %%
print(s1[0:1]) # 0 start and 1 is end
# Out:
# 0    34
# dtype: int64

# %%
print(s1[0::2]) # 0 start and 2 is step
# Out:
# 0    34
# 2    62
# 4    79
# 6    19
# dtype: int64

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ### dict of list

# %%
# A multi dimensional (2d) array like structure along with indices as label.

# %%
# dict of list

df = pd.DataFrame({
    "name" : ["shivani" , "vishva" , "khushi"],
    "age" : [18 , 20 , 25],
    "marks" : [60 , 50 , 99]
    })

df
# Out:
#       name  age  marks
# 0  shivani   18     60
# 1   vishva   20     50
# 2   khushi   25     99

# %%
df["name"]
# Out:
# 0    shivani
# 1     vishva
# 2     khushi
# Name: name, dtype: object

# %%
df[["name" , "marks"]] # for multiple column --> list given
# Out:
#       name  marks
# 0  shivani     60
# 1   vishva     50
# 2   khushi     99

# %%
print(df["name"])
print(df["age"])
print(df["marks"])
# Out:
# 0    shivani
# 1     vishva
# 2     khushi
# Name: name, dtype: object
# 0    18
# 1    20
# 2    25
# Name: age, dtype: int64
# 0    60
# 1    50
# 2    99
# Name: marks, dtype: int64

# %%
df
# Out:
#       name  age  marks
# 0  shivani   18     60
# 1   vishva   20     50
# 2   khushi   25     99

# %%
df["city"] = ["mumbai" , "delhi" , "goa"] # for add value and key
df
# Out:
#       name  age  marks    city
# 0  shivani   18     60  mumbai
# 1   vishva   20     50   delhi
# 2   khushi   25     99     goa

# %%
df["city"] = ["rajkot" , "ahmedabad" , "gujarat"] # for update value and key
df
# Out:
#       name  age  marks       city
# 0  shivani   18     60     rajkot
# 1   vishva   20     50  ahmedabad
# 2   khushi   25     99    gujarat

# %%
print(df["age"].dtype) # type of specifice key of dict
# Out:
# int64

# %%
type(df) # type of dic
# Out:
# pandas.core.frame.DataFrame

# %%
type(s1) # type are given
# Out:
# pandas.core.series.Series

# %%
df["marks"]
# Out:
# 0    60
# 1    50
# 2    99
# Name: marks, dtype: int64

# %%
df ["marks"] + 2 # brodcasting +2 in every element --> oringinal dataframe change nahi hota
# Out:
# 0     62
# 1     52
# 2    101
# Name: marks, dtype: int64

# %%
df
# Out:
#       name  age  marks       city
# 0  shivani   18     60     rajkot
# 1   vishva   20     50  ahmedabad
# 2   khushi   25     99    gujarat

# %%
df ["marks"] - 2 # brodcasting -2 in every element --> oringinal dataframe change nahi hota
# Out:
# 0    58
# 1    48
# 2    97
# Name: marks, dtype: int64

# %%
df ["marks"] * 2 # brodcasting *2 in every element --> oringinal dataframe change nahi hota
# Out:
# 0    120
# 1    100
# 2    198
# Name: marks, dtype: int64

# %%
df ["marks"] / 2 # brodcasting /2 in every element --> oringinal dataframe change nahi hota
# Out:
# 0    30.0
# 1    25.0
# 2    49.5
# Name: marks, dtype: float64

# %%
df
# Out:
#       name  age  marks       city
# 0  shivani   18     60     rajkot
# 1   vishva   20     50  ahmedabad
# 2   khushi   25     99    gujarat

# %%
df["marks"] = df["marks"] + 2 # for changes in original data frame 
df
# Out:
#       name  age  marks       city
# 0  shivani   18     62     rajkot
# 1   vishva   20     52  ahmedabad
# 2   khushi   25    101    gujarat

# %% [markdown]
# # list of list

# %%
df2 =pd.DataFrame([
    ["aryan" , "vansh" , "manav"],
    [20 , 25 , 60],
    [98 , 86 , 67]   
]) 
df2
# Out:
#        0      1      2
# 0  aryan  vansh  manav
# 1     20     25     60
# 2     98     86     67

# %%
df2 = pd.DataFrame([
    ["aryan" , "vansh" , "manav"],
    [20 , 25 , 60],
    [98 , 86 , 67], 
] , index = ["name" , "age" , "marks"])
df2 # raws indexing key
# Out:
#            0      1      2
# name   aryan  vansh  manav
# age       20     25     60
# marks     98     86     67

# %%
df3 = pd.DataFrame([
    ["aryan" , "vansh" , "manav"],
    [20 , 25 , 60],
    [98 , 86 , 67], 
] , columns = ["name" , "age" , "marks"])
df3  # columns indexing key
# Out:
#     name    age  marks
# 0  aryan  vansh  manav
# 1     20     25     60
# 2     98     86     67

# %%
type(df) #df ka type
# Out:
# pandas.core.frame.DataFrame

# %%
type(df3["name"]) #df ka type
# Out:
# pandas.core.series.Series

# %%
df3.dtypes #df ke data ka type
# Out:
# name     object
# age      object
# marks    object
# dtype: object

# %% [markdown]
# ### iloc & loc

# %% [markdown]
# - loc : label based indexing
# - iloc: interger based indexing

# %%
df
# Out:
#       name  age  marks       city
# 0  shivani   18     62     rajkot
# 1   vishva   20     52  ahmedabad
# 2   khushi   25    101    gujarat

# %%
df.iloc[2] # for raw
# Out:
# name      khushi
# age           25
# marks        101
# city     gujarat
# Name: 2, dtype: object

# %%
df.iloc[0:2] # raw , columns
# Out:
#       name  age  marks       city
# 0  shivani   18     62     rajkot
# 1   vishva   20     52  ahmedabad

# %%
df.iloc[0::2] # start , no value is for end which is from at the end , steps
# Out:
#       name  age  marks     city
# 0  shivani   18     62   rajkot
# 2   khushi   25    101  gujarat

# %%
df.iloc[0:2 , 0:2] # first 0:2 ka 0 for start and 2 for end of raws , second 0:2 ka 0 for start and 2 for end of column
# Out:
#       name  age
# 0  shivani   18
# 1   vishva   20

# %%
df
# Out:
#       name  age  marks       city
# 0  shivani   18     62     rajkot
# 1   vishva   20     52  ahmedabad
# 2   khushi   25    101    gujarat

# %%
df.loc[0] # label based
# Out:
# name     shivani
# age           18
# marks         62
# city      rajkot
# Name: 0, dtype: object

# %%
df2
# Out:
#            0      1      2
# name   aryan  vansh  manav
# age       20     25     60
# marks     98     86     67

# %%
df
# Out:
#       name  age  marks       city
# 0  shivani   18     62     rajkot
# 1   vishva   20     52  ahmedabad
# 2   khushi   25    101    gujarat

# %%
df3
# Out:
#     name    age  marks
# 0  aryan  vansh  manav
# 1     20     25     60
# 2     98     86     67

# %%
df3 = df.set_index("name")# how to set index from exiting columns

# %%
df3
# Out:
#          age  marks       city
# name
# shivani   18     62     rajkot
# vishva    20     52  ahmedabad
# khushi    25    101    gujarat

# %%
df3.loc["shivani"] # given all data of shivani
# Out:
# age          18
# marks        62
# city     rajkot
# Name: shivani, dtype: object

# %%
df3.loc[["shivani","khushi","vishva"]]
# Out:
#          age  marks       city
# name
# shivani   18     62     rajkot
# khushi    25    101    gujarat
# vishva    20     52  ahmedabad

# %%
df3.loc[["shivani","khushi"]] # end number is includive
# Out:
#          age  marks     city
# name
# shivani   18     62   rajkot
# khushi    25    101  gujarat

# %%
df3.loc[df3["city"]!="rajkot"] # filter data rajkot vali value hogi to nahi dega
# Out:
#         age  marks       city
# name
# vishva   20     52  ahmedabad
# khushi   25    101    gujarat
